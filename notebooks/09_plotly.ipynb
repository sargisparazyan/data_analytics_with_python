# %%
import pandas as pd
import numpy as np
import plotly.express as px

np.random.seed(42)
px.defaults.template = "plotly_white"

months = pd.date_range("2024-01-01", periods=6, freq="MS")
regions = ["North", "South", "East"]
products = ["A", "B"]

rows = []

for month in months:
    for region in regions:
        for product in products:
            sales = np.random.randint(80, 220)
            customers = np.random.randint(20, 90)
            units = np.random.randint(10, 70)
            
            rows.append([month, region, product, sales, customers, units])

df_plotly = pd.DataFrame(
    rows,
    columns=["month", "region", "product", "sales", "customers", "units"]
)

df_plotly["month_name"] = df_plotly["month"].dt.strftime("%b")
df_plotly.head()
# Out:
#        month region product  sales  customers  units month_name
# 0 2024-01-01  North       A    182         71     38        Jan
# 1 2024-01-01  North       B     94         80     30        Jan
# 2 2024-01-01  South       A    182         43     12        Jan
# 3 2024-01-01  South       B    132         21     33        Jan
# 4 2024-01-01   East       A    117         21     69        Jan

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
monthly_sales = df_plotly.groupby("month", as_index=False)[['customers', 'units','sales']].sum()
monthly_sales
# Out:
#        month  customers  units  sales
# 0 2024-01-01        288    203    807
# 1 2024-02-01        347    289    810
# 2 2024-03-01        380    151    831
# 3 2024-04-01        344    202    855
# 4 2024-05-01        281    207    934
# 5 2024-06-01        252    262    796

# %%
fig = px.line(
    monthly_sales,
    x="month",
    y="sales",
    markers=True,
    title="Line Plot: Monthly Total Sales"
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="Sales",
    
)

fig.show()

# %%
regional_sales = df_plotly.groupby("region", as_index=False)[['customers', 'units','sales']].sum()
regional_sales
# Out:
#   region  customers  units  sales
# 0   East        614    501   1559
# 1  North        605    450   1800
# 2  South        673    363   1674

# %%
fig = px.bar(
    regional_sales,
    x="region",
    y="sales",
    #markers=True,
    title="Regional Total Sales"
)

fig.update_layout(
    xaxis_title="Region",
    yaxis_title="Sales",
    
)

fig.show()

# %%
import pandas as pd
import numpy as np
import plotly.express as px

np.random.seed(42)
px.defaults.template = "plotly_white"

months = pd.date_range("2024-01-01", periods=6, freq="MS")
regions = ["North", "South", "East"]
products = ["A", "B"]

rows = []

for month in months:
    for region in regions:
        for product in products:
            sales = np.random.randint(80, 220)
            customers = np.random.randint(20, 90)
            units = np.random.randint(10, 70)
            
            rows.append([month, region, product, sales, customers, units])

df_plotly = pd.DataFrame(
    rows,
    columns=["month", "region", "product", "sales", "customers", "units"]
)

df_plotly["month_name"] = df_plotly["month"].dt.strftime("%b")
df_plotly.head()
# Out:
#        month region product  sales  customers  units month_name
# 0 2024-01-01  North       A    182         71     38        Jan
# 1 2024-01-01  North       B     94         80     30        Jan
# 2 2024-01-01  South       A    182         43     12        Jan
# 3 2024-01-01  South       B    132         21     33        Jan
# 4 2024-01-01   East       A    117         21     69        Jan

# %%
region_sales = (
    df_plotly.groupby("region", as_index=False)["sales"]
             .sum()
)

region_sales
# Out:
#   region  sales
# 0   East   1559
# 1  North   1800
# 2  South   1674

# %%
fig = px.bar(
    region_sales,
    x="region",
    y="sales",
    title="Total Sales by Region",
    color_discrete_sequence=["#a34e31"]
)


fig.show()

# %%
product_sales = (
    df_plotly.groupby("product", as_index=False)["sales"]
             .sum()
)

product_sales
# Out:
#   product  sales
# 0       A   2699
# 1       B   2334

# %%
fig = px.pie(
    product_sales,
    names="product",
    values="sales",
    hole=0.5,
    title="Share of Total Sales by Product"
)

fig.update_traces(textinfo="label+percent")

fig.show()

# %%
region_product_sales = (
    df_plotly.groupby(["region", "product"], as_index=False)["sales"]
             .sum()
)

region_product_sales
# Out:
#   region product  sales
# 0   East       A    853
# 1   East       B    706
# 2  North       A    888
# 3  North       B    912
# 4  South       A    958
# 5  South       B    716

# %%
fig = px.bar(
    region_product_sales,
    x="region",
    y="sales",
    color="product",
    barmode="group",
    title="Sales by Region and Product",
    color_discrete_sequence=["#3B6EAD", "#AFC4E8"]
)

fig.show()
