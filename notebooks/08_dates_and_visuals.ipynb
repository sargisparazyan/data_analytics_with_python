# %% [markdown]
# # Dates

# %%
import pandas as pd
from datetime import datetime, date, timedelta

# %%
 my_date = date(year = 2025, month = 3, day = 24)

# %%
my_date
# Out:
# datetime.date(2025, 3, 24)

# %%
type(my_date)
# Out:
# datetime.date

# %%
my_time = date(year=2026,month=3, day = 24)

# %%
today = date.today()
today
# Out:
# datetime.date(2026, 3, 24)

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2026, 3, 24, 20, 11, 13, 458570)

# %%
my_date.strftime("%Y-%m-%d")
# Out:
# '2025-03-24'

# %%
my_date.strftime("%Y/%m/%d")
# Out:
# '2025/03/24'

# %%
my_date.strftime("%B-%d-%Y")
# Out:
# 'March-24-2025'

# %%
my_date.strftime("%b-%d-%y")
# Out:
# 'Mar-24-25'

# %%
start_date = my_date
end_date = datetime(2026,4,4)

# %%
delta = end_date - start_date
delta
# Out:
# datetime.timedelta(days=376)

# %%
end_date + delta
end_date + timedelta(weeks = 1)
# Out:
# datetime.date(2026, 4, 11)

# %%
end_date + timedelta(days = 1, seconds=36)
# Out:
# datetime.datetime(2026, 4, 5, 0, 0, 36)

# %% [markdown]
# # Dates with Pandas

# %%
import pandas as pd

df_dates = pd.DataFrame({
    "customer_id": [101, 102, 103, 104, 105],
    "signup_date": ["2024-01-15", "2024-02-20", "2024-03-05", "2024-03-18", "2024-04-10"],
    "last_purchase": ["2024-06-01", "2024-06-15", "2024-07-01", "2024-07-08", "2024-07-12"]
})

df_dates
# Out:
#    customer_id signup_date last_purchase
# 0          101  2024-01-15    2024-06-01
# 1          102  2024-02-20    2024-06-15
# 2          103  2024-03-05    2024-07-01
# 3          104  2024-03-18    2024-07-08
# 4          105  2024-04-10    2024-07-12

# %%
df_dates.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    5 non-null      int64
#  1   signup_date    5 non-null      str
#  2   last_purchase  5 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 352.0 bytes

# %%
df_dates["signup_date"] = pd.to_datetime(df_dates["signup_date"])
df_dates["last_purchase"] = pd.to_datetime(df_dates["last_purchase"])

df_dates.dtypes
# Out:
# customer_id               int64
# signup_date      datetime64[us]
# last_purchase    datetime64[us]
# dtype: object

# %%
df_dates["signup_year"] = df_dates["signup_date"].dt.is_year_start
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year
# 0          101  2024-01-15    2024-06-01        False
# 1          102  2024-02-20    2024-06-15        False
# 2          103  2024-03-05    2024-07-01        False
# 3          104  2024-03-18    2024-07-08        False
# 4          105  2024-04-10    2024-07-12        False

# %%
df_dates["signup_day"] = df_dates["signup_date"].dt.day
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_day
# 0          101  2024-01-15    2024-06-01        False          15
# 1          102  2024-02-20    2024-06-15        False          20
# 2          103  2024-03-05    2024-07-01        False           5
# 3          104  2024-03-18    2024-07-08        False          18
# 4          105  2024-04-10    2024-07-12        False          10

# %%
df_dates["signup_month_name"] = df_dates["signup_date"].dt.month_name()
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_day  \
# 0          101  2024-01-15    2024-06-01        False          15
# 1          102  2024-02-20    2024-06-15        False          20
# 2          103  2024-03-05    2024-07-01        False           5
# 3          104  2024-03-18    2024-07-08        False          18
# 4          105  2024-04-10    2024-07-12        False          10
#
#   signup_month_name
# 0           January
# 1          February
# 2             March
# 3             March
# 4             April

# %%
df_dates["signup_day_name"] = df_dates["signup_date"].dt.day_name()
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_day  \
# 0          101  2024-01-15    2024-06-01        False          15
# 1          102  2024-02-20    2024-06-15        False          20
# 2          103  2024-03-05    2024-07-01        False           5
# 3          104  2024-03-18    2024-07-08        False          18
# 4          105  2024-04-10    2024-07-12        False          10
#
#   signup_month_name signup_day_name
# 0           January          Monday
# 1          February         Tuesday
# 2             March         Tuesday
# 3             March          Monday
# 4             April       Wednesday

# %%
df_dates["is_weekend"] = (df_dates['signup_date'].dt.day_of_week >= 5).astype(int)
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_day  \
# 0          101  2024-01-15    2024-06-01        False          15
# 1          102  2024-02-20    2024-06-15        False          20
# 2          103  2024-03-05    2024-07-01        False           5
# 3          104  2024-03-18    2024-07-08        False          18
# 4          105  2024-04-10    2024-07-12        False          10
#
#   signup_month_name signup_day_name  is_weekend
# 0           January          Monday           0
# 1          February         Tuesday           0
# 2             March         Tuesday           0
# 3             March          Monday           0
# 4             April       Wednesday           0

# %%
df_dates['days_between_signup_purchase']=df_dates['last_purchase'] - df_dates['signup_date']
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_day  \
# 0          101  2024-01-15    2024-06-01        False          15
# 1          102  2024-02-20    2024-06-15        False          20
# 2          103  2024-03-05    2024-07-01        False           5
# 3          104  2024-03-18    2024-07-08        False          18
# 4          105  2024-04-10    2024-07-12        False          10
#
#   signup_month_name signup_day_name  is_weekend days_between_signup_purch  \
# 0           January          Monday           0                 -138 days
# 1          February         Tuesday           0                 -116 days
# 2             March         Tuesday           0                 -118 days
# 3             March          Monday           0                 -112 days
# 4             April       Wednesday           0                  -93 days
#
#   days_between_signup_purchase
# 0                     138 days
# 1                     116 days
# ...

# %%
df_dates.sort_values('signup_date', ascending=False)
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_day  \
# 4          105  2024-04-10    2024-07-12        False          10
# 3          104  2024-03-18    2024-07-08        False          18
# 2          103  2024-03-05    2024-07-01        False           5
# 1          102  2024-02-20    2024-06-15        False          20
# 0          101  2024-01-15    2024-06-01        False          15
#
#   signup_month_name signup_day_name  is_weekend days_between_signup_purch  \
# 4             April       Wednesday           0                  -93 days
# 3             March          Monday           0                 -112 days
# 2             March         Tuesday           0                 -118 days
# 1          February         Tuesday           0                 -116 days
# 0           January          Monday           0                 -138 days
#
#   days_between_signup_purchase
# 4                      93 days
# 3                     112 days
# ...

# %%
list(pd.date_range(start="2024-07-01", periods=7, freq="D"))
# Out:
# [Timestamp('2024-07-01 00:00:00'),
#  Timestamp('2024-07-02 00:00:00'),
#  Timestamp('2024-07-03 00:00:00'),
#  Timestamp('2024-07-04 00:00:00'),
#  Timestamp('2024-07-05 00:00:00'),
#  Timestamp('2024-07-06 00:00:00'),
#  Timestamp('2024-07-07 00:00:00')]

# %%
import pandas as pd

some_date = pd.Timestamp("2024-07-15")

print(f"Original date: {some_date}")
print(f"Beginning of month: {some_date.to_period('M').start_time}")
print(f"End of month: {some_date.to_period('M').end_time}")
# Out:
# Original date: 2024-07-15 00:00:00
# Beginning of month: 2024-07-01 00:00:00
# End of month: 2024-07-31 23:59:59.999999

# %%
df_dates['bom'] = df_dates['signup_date'].dt.to_period('M').dt.start_time.dt.date
df_dates['eom'] = df_dates['signup_date'].dt.to_period('M').dt.end_time.dt.date
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_day  \
# 0          101  2024-01-15    2024-06-01        False          15
# 1          102  2024-02-20    2024-06-15        False          20
# 2          103  2024-03-05    2024-07-01        False           5
# 3          104  2024-03-18    2024-07-08        False          18
# 4          105  2024-04-10    2024-07-12        False          10
#
#   signup_month_name signup_day_name  is_weekend days_between_signup_purch  \
# 0           January          Monday           0                 -138 days
# 1          February         Tuesday           0                 -116 days
# 2             March         Tuesday           0                 -118 days
# 3             March          Monday           0                 -112 days
# 4             April       Wednesday           0                  -93 days
#
#   days_between_signup_purchase         bom         eom
# 0                     138 days  2024-01-01  2024-01-31
# ...
