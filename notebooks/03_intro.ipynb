# %%
a = 0
type(a)
# Out:
# int

# %%
a = -1
type(a)
# Out:
# int

# %%
a= -1.58848858848
type(a)
# Out:
# float

# %%
pow(2,3)
# Out:
# 8

# %%
r = 100
t = 0.2
revenue = r * (1+t
               )

# %%
revenue
# Out:
# 120.0

# %%
sales = [100,200,300,400]

# %%
sales[0]
sales[-1]
# Out:
# 400

# %%
sales[0]
# Out:
# 100

# %%
len(sales)
# Out:
# 4

# %%
sales.remove(200)

# %%
sales
# Out:
# [100, 300, 400]

# %%
total = 0
for value in sales:
    total += value

total
# Out:
# 800

# %%
import pandas as pd

data = {
    "name": ["Anna", "David", "Mariam"],
    "revenue": [150, 220, 90],
    "city": ["Yerevan", "Tbilisi", "Warsaw"]
}

df = pd.DataFrame(data)
df
# Out:
#      name  revenue     city
# 0    Anna      150  Yerevan
# 1   David      220  Tbilisi
# 2  Mariam       90   Warsaw

# %%
df.info()
df.shape
df.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     3 non-null      str
#  1   revenue  3 non-null      int64
#  2   city     3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes
# Index(['name', 'revenue', 'city'], dtype='str')

# %%
df["revenue"]
df[["name", "revenue"]]
# Out:
#      name  revenue
# 0    Anna      150
# 1   David      220
# 2  Mariam       90

# %%
df["revenue"]
# Out:
# 0    150
# 1    220
# 2     90
# Name: revenue, dtype: int64

# %%
data
# Out:
# {'name': ['Anna', 'David', 'Mariam'],
#  'revenue': [150, 220, 90],
#  'city': ['Yerevan', 'Tbilisi', 'Warsaw']}

# %%
df.drop("city", axis=1)
# Out:
#      name  revenue
# 0    Anna      150
# 1   David      220
# 2  Mariam       90

# %%
data
# Out:
# {'name': ['Anna', 'David', 'Mariam'],
#  'revenue': [150, 220, 90],
#  'city': ['Yerevan', 'Tbilisi', 'Warsaw']}

# %%
df = df.drop("city", axis=1)
df
# Out:
#      name  revenue
# 0    Anna      150
# 1   David      220
# 2  Mariam       90

# %%
df
# Out:
#      name  revenue
# 0    Anna      150
# 1   David      220
# 2  Mariam       90

# %%
data
# Out:
# {'name': ['Anna', 'David', 'Mariam'],
#  'revenue': [150, 220, 90],
#  'city': ['Yerevan', 'Tbilisi', 'Warsaw']}

# %%
df
# Out:
#      name  revenue
# 0    Anna      150
# 1   David      220
# 2  Mariam       90

# %%
df.loc[df["revenue"] < 100, "segment"] = "Low"
df.loc[df["revenue"] >= 100, "segment"] = "High"
df
# Out:
#      name  revenue segment
# 0    Anna      150    High
# 1   David      220    High
# 2  Mariam       90     Low

# %%
revenue = 150

if revenue > 100:
    print("High revenue")
else:
    print("Normal revenue")
# Out:
# High revenue

# %%
revenue = 90

# %%
revenue = 90

if revenue > 100:
    print("High revenue")
else:
    print("Normal revenue")
# Out:
# Normal revenue

# %%
sales = [100, 200, 150, 50]

for value in sales:
    if value > 120:
        print("High sale:", value)
# Out:
# High sale: 200
# High sale: 150

# %%
sales = [100, 200, 150, 50]

for value in sales:
    if value > 120:
        print("High sale:", value)
    if value < 110:
         print("Low Value", value)
# Out:
# Low Value 100
# High sale: 200
# High sale: 150
# Low Value 50

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(3):
    for j in range(2):
        print("i =", i, ", j =", j)
# Out:
# i = 0 , j = 0
# i = 0 , j = 1
# i = 1 , j = 0
# i = 1 , j = 1
# i = 2 , j = 0
# i = 2 , j = 1

# %%
for value in sales:
    print(value)
# Out:
# 100
# 200
# 150
# 50

# %%
sales = [100, 200, 150]

new_sales = []

for value in sales:
    new_sales.append(value * 1.2)

new_sales
# Out:
# [120.0, 240.0, 180.0]

# %%
sales = [100, 200, 150]

new_sales = [value * 1.2 for value in sales]
new_sales
# Out:
# [120.0, 240.0, 180.0]

# %%
sales = [100, 200, 150, 50]

high_sales = [value for value in sales if value > 120]
high_sales
# Out:
# [200, 150]

# %%
high_sales = []

for value in sales:
    if value > 120:
        high_sales.append(value)

high_sales
# Out:
# [200, 150]

# %%
sales = [100, 200, 150, 50]

labels = ["High" if value > 120 else "Low" for value in sales]
labels
# Out:
# ['Low', 'High', 'High', 'Low']

# %%
a = 6
b = 5
a,b = b,a
print(a)
print(b)
# Out:
# 5
# 6

# %%
list = ['data1.csv', 'data2.csv', 'data3.csv']
for  i in list:
  print(f'mer dataneri faylern en {i}')
# Out:
# mer dataneri faylern en data1.csv
# mer dataneri faylern en data2.csv
# mer dataneri faylern en data3.csv
